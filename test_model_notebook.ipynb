# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
from tqdm import tqdm
import requests
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import backend as K
import cv2
import sys
import seaborn as sns
import pandas as pd
import json
import re


np.random.seed(1)

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
sys.path.append("/content/gdrive/MyDrive/Proactive ware/")
from utils.utils import *

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# To Download weights of the trained model use the cells below:

# %%
# !gdown --id 1gd7UFG76JJq_VUcApHMUFRRpjKlQM6l1

# %%
# !unzip ./solar_new -d ./solar_model

# %% [markdown]
# There is a function named `test_model()` in `utils` module. You can run predictions on images using this function.
#
# This function either takes a(or a list of) string value(s), containing a path/link to an image (Video Support is not implemented), or takes a batch of images.

# %% [markdown]
# Test using a link:

# %%
image_path = "https://i.ytimg.com/vi/cj91qZxMtbc/mqdefault.jpg"
path_to_model = "./solar_model"
test_model(
    image_path,
    path_to_model
)

# %% [markdown]
# Or test using an already downloaded image:

# %%
# !wget "https://i.ytimg.com/vi/cj91qZxMtbc/mqdefault.jpg" -O test.jpeg
# Out:
# /usr/bin/zsh: /home/amiralism/miniconda3/envs/tf2./lib/libtinfo.so.6: no version information available (required by /usr/bin/zsh)
# --2023-05-24 13:13:07--  https://i.ytimg.com/vi/cj91qZxMtbc/mqdefault.jpg
# Resolving i.ytimg.com (i.ytimg.com)... 142.250.185.246, 142.250.186.86, 142.250.186.118, ...
# Connecting to i.ytimg.com (i.ytimg.com)|142.250.185.246|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11709 (11K) [image/jpeg]
# Saving to: ‘test.jpeg’
#
# test.jpeg           100%[===================>]  11.43K  --.-KB/s    in 0.008s
#
# 2023-05-24 13:13:07 (1.39 MB/s) - ‘test.jpeg’ saved [11709/11709]

# %%
test_model(
    "test.jpeg",
    path_to_model,
)
